# %% [markdown]
# ### Import python library Numpy, pandas, Matplotlib and seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('default')
# %matplotlib inline

# %% [markdown]
# ### Load the 9 station data sets which are in csv file type. Data are from Merra-2 satellite.

# %%
delhi=pd.read_csv('DELHI NEW.csv')
jpr=pd.read_csv('JAIPUR NEW.csv')
bng=pd.read_csv('BANGALORE NEW.csv')
kol=pd.read_csv('KOLKATA NEW.csv')
vgp=pd.read_csv('VISHAKHAPATNAM NEW.csv')
chn=pd.read_csv('CHENNAI NEW.csv')
mumbai=pd.read_csv('MUMBAI NEW.csv')
mang=pd.read_csv('MANGALURU NEW.csv')
kochi=pd.read_csv('KOCHIN NEW.csv')
Years=[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]

# %% [markdown]
# ### Extracting temperature,relative humidity and precipitation data of 9 different station.

# %%
delhitemp=delhi[(delhi.PARAMETER=='T2M')]
jprtemp=jpr[(jpr.PARAMETER=='T2M')]
bngtemp=bng[(bng.PARAMETER=='T2M')]
koltemp=kol[(kol.PARAMETER=='T2M')]
vgptemp=vgp[(vgp.PARAMETER=='T2M')]
chntemp=chn[(chn.PARAMETER=='T2M')]
mumbaitemp=mumbai[(mumbai.PARAMETER=='T2M')]
mangtemp=mang[(mang.PARAMETER=='T2M')]
kochitemp=kochi[(kochi.PARAMETER=='T2M')]

delhihum=delhi[(delhi.PARAMETER=='RH2M')]
jprhum=jpr[(jpr.PARAMETER=='RH2M')]
bnghum=bng[(bng.PARAMETER=='RH2M')]
kolhum=kol[(kol.PARAMETER=='RH2M')]
vgphum=vgp[(vgp.PARAMETER=='RH2M')]
chnhum=chn[(chn.PARAMETER=='RH2M')]
mumbaihum=mumbai[(mumbai.PARAMETER=='RH2M')]
manghum=mang[(mang.PARAMETER=='RH2M')]
kochihum=kochi[(kochi.PARAMETER=='RH2M')]

delhirain=delhi[(delhi.PARAMETER=='PRECTOTCORR')]
jprrain=jpr[(jpr.PARAMETER=='PRECTOTCORR')]
bngrain=bng[(bng.PARAMETER=='PRECTOTCORR')]
kolrain=kol[(kol.PARAMETER=='PRECTOTCORR')]
vgprain=vgp[(vgp.PARAMETER=='PRECTOTCORR')]
chnrain=chn[(chn.PARAMETER=='PRECTOTCORR')]
mumbairain=mumbai[(mumbai.PARAMETER=='PRECTOTCORR')]
mangrain=mang[(mang.PARAMETER=='PRECTOTCORR')]
kochirain=kochi[(kochi.PARAMETER=='PRECTOTCORR')]

# %% [markdown]
# ### In this block of code, for all station's temperature, relative humidity and precipitation is catagorized for 3 different season, Premonsoon monsoon and postmonsoon.

# %%
#TEMPERATURE
delhitemp['PREMONSOON_TEMP (^OC)']=delhitemp[['MAR','APR','MAY']].mean(axis=1)
jprtemp['PREMONSOON_TEMP (^OC)']=jprtemp[['MAR','APR','MAY']].mean(axis=1)
bngtemp['PREMONSOON_TEMP (^OC)']=bngtemp[['MAR','APR','MAY']].mean(axis=1)
delhitemp['MONSOON_TEMP (^OC)']=delhitemp[['JUN','JUL','AUG','SEP']].mean(axis=1)
jprtemp['MONSOON_TEMP (^OC)']=jprtemp[['JUN','JUL','AUG','SEP']].mean(axis=1)
bngtemp['MONSOON_TEMP (^OC)']=bngtemp[['JUN','JUL','AUG','SEP']].mean(axis=1)
delhitemp['POSTMONSOON_TEMP (^OC)']=delhitemp[['OCT','NOV','DEC']].mean(axis=1)
jprtemp['POSTMONSOON_TEMP (^OC)']=jprtemp[['OCT','NOV','DEC']].mean(axis=1)
bngtemp['POSTMONSOON_TEMP (^OC)']=bngtemp[['OCT','NOV','DEC']].mean(axis=1)

koltemp['PREMONSOON_TEMP (^OC)']=koltemp[['MAR','APR','MAY']].mean(axis=1)
vgptemp['PREMONSOON_TEMP (^OC)']=vgptemp[['MAR','APR','MAY']].mean(axis=1)
chntemp['PREMONSOON_TEMP (^OC)']=chntemp[['MAR','APR','MAY']].mean(axis=1)
koltemp['MONSOON_TEMP (^OC)']=koltemp[['JUN','JUL','AUG','SEP']].mean(axis=1)
vgptemp['MONSOON_TEMP (^OC)']=vgptemp[['JUN','JUL','AUG','SEP']].mean(axis=1)
chntemp['MONSOON_TEMP (^OC)']=chntemp[['JUN','JUL','AUG','SEP']].mean(axis=1)
koltemp['POSTMONSOON_TEMP (^OC)']=koltemp[['OCT','NOV','DEC']].mean(axis=1)
vgptemp['POSTMONSOON_TEMP (^OC)']=vgptemp[['OCT','NOV','DEC']].mean(axis=1)
chntemp['POSTMONSOON_TEMP (^OC)']=chntemp[['OCT','NOV','DEC']].mean(axis=1)

mumbaitemp['PREMONSOON_TEMP (^OC)']=mumbaitemp[['MAR','APR','MAY']].mean(axis=1)
mangtemp['PREMONSOON_TEMP (^OC)']=mangtemp[['MAR','APR','MAY']].mean(axis=1)
kochitemp['PREMONSOON_TEMP (^OC)']=kochitemp[['MAR','APR','MAY']].mean(axis=1)
mumbaitemp['MONSOON_TEMP (^OC)']=mumbaitemp[['JUN','JUL','AUG','SEP']].mean(axis=1)
mangtemp['MONSOON_TEMP (^OC)']=mangtemp[['JUN','JUL','AUG','SEP']].mean(axis=1)
kochitemp['MONSOON_TEMP (^OC)']=kochitemp[['JUN','JUL','AUG','SEP']].mean(axis=1)
mumbaitemp['POSTMONSOON_TEMP (^OC)']=mumbaitemp[['OCT','NOV','DEC']].mean(axis=1)
mangtemp['POSTMONSOON_TEMP (^OC)']=mangtemp[['OCT','NOV','DEC']].mean(axis=1)
kochitemp['POSTMONSOON_TEMP (^OC)']=kochitemp[['OCT','NOV','DEC']].mean(axis=1)

#RELATIVE HUMIDITY
delhihum['PREMONSOON_HUM (%)']=delhihum[['MAR','APR','MAY']].mean(axis=1)
jprhum['PREMONSOON_HUM (%)']=jprhum[['MAR','APR','MAY']].mean(axis=1)
bnghum['PREMONSOON_HUM (%)']=bnghum[['MAR','APR','MAY']].mean(axis=1)
delhihum['MONSOON_HUM (%)']=delhihum[['JUN','JUL','AUG','SEP']].mean(axis=1)
jprhum['MONSOON_HUM (%)']=jprhum[['JUN','JUL','AUG','SEP']].mean(axis=1)
bnghum['MONSOON_HUM (%)']=bnghum[['JUN','JUL','AUG','SEP']].mean(axis=1)
delhihum['POSTMONSOON_HUM (%)']=delhihum[['OCT','NOV','DEC']].mean(axis=1)
jprhum['POSTMONSOON_HUM (%)']=jprhum[['OCT','NOV','DEC']].mean(axis=1)
bnghum['POSTMONSOON_HUM (%)']=bnghum[['OCT','NOV','DEC']].mean(axis=1)

kolhum['PREMONSOON_HUM (%)']=kolhum[['MAR','APR','MAY']].mean(axis=1)
vgphum['PREMONSOON_HUM (%)']=vgphum[['MAR','APR','MAY']].mean(axis=1)
chnhum['PREMONSOON_HUM (%)']=chnhum[['MAR','APR','MAY']].mean(axis=1)
kolhum['MONSOON_HUM (%)']=kolhum[['JUN','JUL','AUG','SEP']].mean(axis=1)
vgphum['MONSOON_HUM (%)']=vgphum[['JUN','JUL','AUG','SEP']].mean(axis=1)
chnhum['MONSOON_HUM (%)']=chnhum[['JUN','JUL','AUG','SEP']].mean(axis=1)
kolhum['POSTMONSOON_HUM (%)']=kolhum[['OCT','NOV','DEC']].mean(axis=1)
vgphum['POSTMONSOON_HUM (%)']=vgphum[['OCT','NOV','DEC']].mean(axis=1)
chnhum['POSTMONSOON_HUM (%)']=chnhum[['OCT','NOV','DEC']].mean(axis=1)

mumbaihum['PREMONSOON_HUM (%)']=mumbaihum[['MAR','APR','MAY']].mean(axis=1)
manghum['PREMONSOON_HUM (%)']=manghum[['MAR','APR','MAY']].mean(axis=1)
kochihum['PREMONSOON_HUM (%)']=kochihum[['MAR','APR','MAY']].mean(axis=1)
mumbaihum['MONSOON_HUM (%)']=mumbaihum[['JUN','JUL','AUG','SEP']].mean(axis=1)
manghum['MONSOON_HUM (%)']=manghum[['JUN','JUL','AUG','SEP']].mean(axis=1)
kochihum['MONSOON_HUM (%)']=kochihum[['JUN','JUL','AUG','SEP']].mean(axis=1)
mumbaihum['POSTMONSOON_HUM (%)']=mumbaihum[['OCT','NOV','DEC']].mean(axis=1)
manghum['POSTMONSOON_HUM (%)']=manghum[['OCT','NOV','DEC']].mean(axis=1)
kochihum['POSTMONSOON_HUM (%)']=kochihum[['OCT','NOV','DEC']].mean(axis=1)

# RAINFALL
delhirain['PREMONSOON_RAIN (mm/day)']=delhirain[['MAR','APR','MAY']].mean(axis=1)
jprrain['PREMONSOON_RAIN (mm/day)']=jprrain[['MAR','APR','MAY']].mean(axis=1)
bngrain['PREMONSOON_RAIN (mm/day)']=bngrain[['MAR','APR','MAY']].mean(axis=1)
delhirain['MONSOON_RAIN (mm/day)']=delhirain[['JUN','JUL','AUG','SEP']].mean(axis=1)
jprrain['MONSOON_RAIN (mm/day)']=jprrain[['JUN','JUL','AUG','SEP']].mean(axis=1)
bngrain['MONSOON_RAIN (mm/day)']=bngrain[['JUN','JUL','AUG','SEP']].mean(axis=1)
delhirain['POSTMONSOON_RAIN (mm/day)']=delhirain[['OCT','NOV','DEC']].mean(axis=1)
jprrain['POSTMONSOON_RAIN (mm/day)']=jprrain[['OCT','NOV','DEC']].mean(axis=1)
bngrain['POSTMONSOON_RAIN (mm/day)']=bngrain[['OCT','NOV','DEC']].mean(axis=1)
 
kolrain['PREMONSOON_RAIN (mm/day)']=kolrain[['MAR','APR','MAY']].mean(axis=1)
vgprain['PREMONSOON_RAIN (mm/day)']=vgprain[['MAR','APR','MAY']].mean(axis=1)
chnrain['PREMONSOON_RAIN (mm/day)']=chnrain[['MAR','APR','MAY']].mean(axis=1)
kolrain['MONSOON_RAIN (mm/day)']=kolrain[['JUN','JUL','AUG','SEP']].mean(axis=1)
vgprain['MONSOON_RAIN (mm/day)']=vgprain[['JUN','JUL','AUG','SEP']].mean(axis=1)
chnrain['MONSOON_RAIN (mm/day)']=chnrain[['JUN','JUL','AUG','SEP']].mean(axis=1)
kolrain['POSTMONSOON_RAIN (mm/day)']=kolrain[['OCT','NOV','DEC']].mean(axis=1)
vgprain['POSTMONSOON_RAIN (mm/day)']=vgprain[['OCT','NOV','DEC']].mean(axis=1)
chnrain['POSTMONSOON_RAIN (mm/day)']=chnrain[['OCT','NOV','DEC']].mean(axis=1)
 

mumbairain['PREMONSOON_RAIN (mm/day)']=mumbairain[['MAR','APR','MAY']].mean(axis=1)
mangrain['PREMONSOON_RAIN (mm/day)']=mangrain[['MAR','APR','MAY']].mean(axis=1)
kochirain['PREMONSOON_RAIN (mm/day)']=kochirain[['MAR','APR','MAY']].mean(axis=1)
mumbairain['MONSOON_RAIN (mm/day)']=mumbairain[['JUN','JUL','AUG','SEP']].mean(axis=1)
mangrain['MONSOON_RAIN (mm/day)']=mangrain[['JUN','JUL','AUG','SEP']].mean(axis=1)
kochirain['MONSOON_RAIN (mm/day)']=kochirain[['JUN','JUL','AUG','SEP']].mean(axis=1)
mumbairain['POSTMONSOON_RAIN (mm/day)']=mumbairain[['OCT','NOV','DEC']].mean(axis=1)
mangrain['POSTMONSOON_RAIN (mm/day)']=mangrain[['OCT','NOV','DEC']].mean(axis=1)
kochirain['POSTMONSOON_RAIN (mm/day)']=kochirain[['OCT','NOV','DEC']].mean(axis=1)
# Out:
# C:\Users\Ujjwal Bera\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Ujjwal Bera\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Ujjwal Bera\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ### Plot and visualization of atmospheric parameters for different locations for different season.

# %%
#INLAND TEMPERATURE
plt.figure(figsize=(9,3), dpi=150)
plt.title('INLAND                                                                     PREMONSOON (MAR-MAY)')
plt.ylabel('TEMPERATURE (^OC)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(18,34)
plt.plot(Years,delhitemp['PREMONSOON_TEMP (^OC)'],label='DELHI',color='black')
plt.plot(Years,jprtemp['PREMONSOON_TEMP (^OC)'],label='JAIPUR',color='blue')
plt.plot(Years,bngtemp['PREMONSOON_TEMP (^OC)'],label='BANGALORE',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('INLAND                                                                       MONSOON (JUNE-SEPT)')
plt.ylabel('TEMPERATURE (^OC)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(18,34)
plt.plot(Years,delhitemp['MONSOON_TEMP (^OC)'],label='DELHI',color='black')
plt.plot(Years,jprtemp['MONSOON_TEMP (^OC)'],label='JAIPUR',color='blue')
plt.plot(Years,bngtemp['MONSOON_TEMP (^OC)'],label='BANGALORE',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('INLAND                                                                       POSTMONSOON (OCT-DEC)')
plt.ylabel('TEMPERATURE (^OC)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(18,34)
plt.plot(Years,delhitemp['POSTMONSOON_TEMP (^OC)'],label='DELHI',color='black')
plt.plot(Years,jprtemp['POSTMONSOON_TEMP (^OC)'],label='JAIPUR',color='blue')
plt.plot(Years,bngtemp['POSTMONSOON_TEMP (^OC)'],label='BANGALORE',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

#EAST COAST TEMPERATURE
plt.figure(figsize=(9,3), dpi=150)
plt.title('EAST-COAST                                                                     PREMONSOON (MAR-MAY)')
plt.ylabel('TEMPERATURE (^OC)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(18,34)
plt.plot(Years,koltemp['PREMONSOON_TEMP (^OC)'],label='KOLKATA',color='black')
plt.plot(Years,vgptemp['PREMONSOON_TEMP (^OC)'],label='VISHAKHAPATNAM',color='blue')
plt.plot(Years,chntemp['PREMONSOON_TEMP (^OC)'],label='CHENNAI',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('EAST-COAST                                                                     MONSOON (JUNE-SEPT)')
plt.ylabel('TEMPERATURE (^OC)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(18,34)
plt.plot(Years,koltemp['MONSOON_TEMP (^OC)'],label='KOLKATA',color='black')
plt.plot(Years,vgptemp['MONSOON_TEMP (^OC)'],label='VISHAKHAPATNAM',color='blue')
plt.plot(Years,chntemp['MONSOON_TEMP (^OC)'],label='CHENNAI',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('EAST-COAST                                                                     POSTMONSOON (OCT-DEC)')
plt.ylabel('TEMPERATURE (^OC)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(18,34)
plt.plot(Years,koltemp['POSTMONSOON_TEMP (^OC)'],label='KOLKATA',color='black')
plt.plot(Years,vgptemp['POSTMONSOON_TEMP (^OC)'],label='VISHAKHAPATNAM',color='blue')
plt.plot(Years,chntemp['POSTMONSOON_TEMP (^OC)'],label='CHENNAI',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

#WEST COAST TEMPERATURE
plt.figure(figsize=(9,3), dpi=150)
plt.title('WEST-COAST                                                                     PREMONSOON (MAR-MAY)')
plt.ylabel('TEMPERATURE (^OC)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(18,34)
plt.plot(Years,mumbaitemp['PREMONSOON_TEMP (^OC)'],label='MUMBAI',color='black')
plt.plot(Years,mangtemp['PREMONSOON_TEMP (^OC)'],label='MANGALURU',color='blue')
plt.plot(Years,kochitemp['PREMONSOON_TEMP (^OC)'],label='KOCHIN',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('WEST-COAST                                                                     MONSOON (JUNE-SEPT)')
plt.ylabel('TEMPERATURE (^OC)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(18,34)
plt.plot(Years,mumbaitemp['MONSOON_TEMP (^OC)'],label='MUMBAI',color='black')
plt.plot(Years,mangtemp['MONSOON_TEMP (^OC)'],label='MANGALURU',color='blue')
plt.plot(Years,kochitemp['MONSOON_TEMP (^OC)'],label='KOCHIN',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('WEST-COAST                                                                     POSTMONSOON (OCT-DEC)')
plt.ylabel('TEMPERATURE (^OC)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(18,34)
plt.plot(Years,mumbaitemp['POSTMONSOON_TEMP (^OC)'],label='MUMBAI',color='black')
plt.plot(Years,mangtemp['POSTMONSOON_TEMP (^OC)'],label='MANGALURU',color='blue')
plt.plot(Years,kochitemp['POSTMONSOON_TEMP (^OC)'],label='KOCHIN',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

#INLAND HUMIDITY
plt.figure(figsize=(9,3), dpi=150)
plt.title('INLAND                                                                     PREMONSOON (MAR-MAY)')
plt.ylabel('RELATIVE HUMIDITY (%)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(10,90)
plt.plot(Years,delhihum['PREMONSOON_HUM (%)'],label='DELHI',color='black')
plt.plot(Years,jprhum['PREMONSOON_HUM (%)'],label='JAIPUR',color='blue')
plt.plot(Years,bnghum['PREMONSOON_HUM (%)'],label='BANGALORE',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('INLAND                                                                     MONSOON (JUNE-SEPT)')
plt.ylabel('RELATIVE HUMIDITY (%)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(10,90)
plt.plot(Years,delhihum['MONSOON_HUM (%)'],label='DELHI',color='black')
plt.plot(Years,jprhum['MONSOON_HUM (%)'],label='JAIPUR',color='blue')
plt.plot(Years,bnghum['MONSOON_HUM (%)'],label='BANGALORE',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('INLAND                                                                     POSTMONSOON (OCT-DEC)')
plt.ylabel('RELATIVE HUMIDITY (%)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(10,90)
plt.plot(Years,delhihum['POSTMONSOON_HUM (%)'],label='DELHI',color='black')
plt.plot(Years,jprhum['POSTMONSOON_HUM (%)'],label='JAIPUR',color='blue')
plt.plot(Years,bnghum['POSTMONSOON_HUM (%)'],label='BANGALORE',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()


plt.figure(figsize=(9,3), dpi=150)
plt.title('EAST-COAST                                                                     PREMONSOON (MAR-MAY)')
plt.ylabel('RELATIVE HUMIDITY (%)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(10,90)
plt.plot(Years,kolhum['PREMONSOON_HUM (%)'],label='KOLKATA',color='black')
plt.plot(Years,vgphum['PREMONSOON_HUM (%)'],label='VISHAKHAPATNAM',color='blue')
plt.plot(Years,chnhum['PREMONSOON_HUM (%)'],label='CHENNAI',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('EAST-COAST                                                                     MONSOON (JUNE-SEPT)')
plt.ylabel('RELATIVE HUMIDITY (%)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(10,90)
plt.plot(Years,kolhum['MONSOON_HUM (%)'],label='KOLKATA',color='black')
plt.plot(Years,vgphum['MONSOON_HUM (%)'],label='VISHAKHAPATNAM',color='blue')
plt.plot(Years,chnhum['MONSOON_HUM (%)'],label='CHENNAI',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('EAST-COAST                                                                     POSTMONSOON (OCT-DEC)')
plt.ylabel('RELATIVE HUMIDITY (%)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(10,90)
plt.plot(Years,kolhum['POSTMONSOON_HUM (%)'],label='KOLKATA',color='black')
plt.plot(Years,vgphum['POSTMONSOON_HUM (%)'],label='VISHAKHAPATNAM',color='blue')
plt.plot(Years,chnhum['POSTMONSOON_HUM (%)'],label='CHENNAI',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()


plt.figure(figsize=(9,3), dpi=150)
plt.title('WEST-COAST                                                                     PREMONSOON (MAR-MAY)')
plt.ylabel('RELATIVE HUMIDITY (%)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(10,90)
plt.plot(Years,mumbaihum['PREMONSOON_HUM (%)'],label='MUMBAI',color='black')
plt.plot(Years,manghum['PREMONSOON_HUM (%)'],label='MANGALURU',color='blue')
plt.plot(Years,kochihum['PREMONSOON_HUM (%)'],label='KOCHIN',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('WEST-COAST                                                                     MONSOON (JUNE-SEPT)')
plt.ylabel('RELATIVE HUMIDITY (%)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(10,90)
plt.plot(Years,mumbaihum['MONSOON_HUM (%)'],label='MUMBAI',color='black')
plt.plot(Years,manghum['MONSOON_HUM (%)'],label='MANGALURU',color='blue')
plt.plot(Years,kochihum['MONSOON_HUM (%)'],label='KOCHIN',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('WEST-COAST                                                                     POSTMONSOON (OCT-DEC)')
plt.ylabel('RELATIVE HUMIDITY (%)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(10,90)
plt.plot(Years,mumbaihum['POSTMONSOON_HUM (%)'],label='MUMBAI',color='black')
plt.plot(Years,manghum['MONSOON_HUM (%)'],label='MANGALURU',color='blue')
plt.plot(Years,kochihum['MONSOON_HUM (%)'],label='KOCHIN',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

# INLAND RAINFALL
plt.figure(figsize=(9,3), dpi=150)
plt.title('INLAND                                                                     PREMONSOON (MAR-MAY)')
plt.ylabel('RAINFALL (mm/day)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(0,20)
plt.plot(Years,delhirain['PREMONSOON_RAIN (mm/day)'],label='DELHI',color='black')
plt.plot(Years,jprrain['PREMONSOON_RAIN (mm/day)'],label='JAIPUR',color='blue')
plt.plot(Years,bngrain['PREMONSOON_RAIN (mm/day)'],label='BANGALORE',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('INLAND                                                                      MONSOON (JUNE-SEPT)')
plt.ylabel('RAINFALL (mm/day)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(0,20)
plt.plot(Years,delhirain['MONSOON_RAIN (mm/day)'],label='DELHI',color='black')
plt.plot(Years,jprrain['MONSOON_RAIN (mm/day)'],label='JAIPUR',color='blue')
plt.plot(Years,bngrain['MONSOON_RAIN (mm/day)'],label='BANGALORE',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('INLAND                                                                      POSTMONSOON (OCT-DEC)')
plt.ylabel('RAINFALL (mm/day)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(0,20)
plt.plot(Years,delhirain['POSTMONSOON_RAIN (mm/day)'],label='DELHI',color='black')
plt.plot(Years,jprrain['POSTMONSOON_RAIN (mm/day)'],label='JAIPUR',color='blue')
plt.plot(Years,bngrain['POSTMONSOON_RAIN (mm/day)'],label='BANGALORE',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()


plt.figure(figsize=(9,3), dpi=150)
plt.title('EAST-COAST                                                                     PREMONSOON (MAR-MAY)')
plt.ylabel('RAINFALL (mm/day)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(0,20)
plt.plot(Years,kolrain['PREMONSOON_RAIN (mm/day)'],label='KOLKATA',color='black')
plt.plot(Years,vgprain['PREMONSOON_RAIN (mm/day)'],label='VISHAKHAPATNAM',color='blue')
plt.plot(Years,chnrain['PREMONSOON_RAIN (mm/day)'],label='CHENNAI',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('EAST-COAST                                                                     MONSOON (JUNE-SEPT)')
plt.ylabel('RAINFALL (mm/day)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(0,20)
plt.plot(Years,kolrain['MONSOON_RAIN (mm/day)'],label='KOLKATA',color='black')
plt.plot(Years,vgprain['MONSOON_RAIN (mm/day)'],label='VISHAKHAPATNAM',color='blue')
plt.plot(Years,chnrain['MONSOON_RAIN (mm/day)'],label='CHENNAI',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('EAST-COAST                                                                     POSTMONSOON (OCT-DEC)')
plt.ylabel('RAINFALL (mm/day)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(0,20)
plt.plot(Years,kolrain['POSTMONSOON_RAIN (mm/day)'],label='KOLKATA',color='black')
plt.plot(Years,vgprain['POSTMONSOON_RAIN (mm/day)'],label='VISHAKHAPATNAM',color='blue')
plt.plot(Years,chnrain['POSTMONSOON_RAIN (mm/day)'],label='CHENNAI',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()


plt.figure(figsize=(9,3), dpi=150)
plt.title('WEST-COAST                                                                     PREMONSOON (MAR-MAY)')
plt.ylabel('RAINFALL (mm/day)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(0,20)
plt.plot(Years,mumbairain['PREMONSOON_RAIN (mm/day)'],label='MUMBAI',color='black')
plt.plot(Years,mangrain['PREMONSOON_RAIN (mm/day)'],label='MANGALURU',color='blue')
plt.plot(Years,kochirain['PREMONSOON_RAIN (mm/day)'],label='KOCHIN',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('WEST-COAST                                                                     MONSOON (JUNE-SEPT)')
plt.ylabel('RAINFALL (mm/day)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(0,40)
plt.plot(Years,mumbairain['MONSOON_RAIN (mm/day)'],label='MUMBAI',color='black')
plt.plot(Years,mangrain['MONSOON_RAIN (mm/day)'],label='MANGALURU',color='blue')
plt.plot(Years,kochirain['MONSOON_RAIN (mm/day)'],label='KOCHIN',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()

plt.figure(figsize=(9,3), dpi=150)
plt.title('WEST-COAST                                                                     POSTMONSOON (OCT-DEC)')
plt.ylabel('RAINFALL (mm/day)')
plt.xlabel('YEAR')
plt.xticks(Years,rotation=45)
plt.ylim(0,20)
plt.plot(Years,mumbairain['POSTMONSOON_RAIN (mm/day)'],label='MUMBAI',color='black')
plt.plot(Years,mangrain['POSTMONSOON_RAIN (mm/day)'],label='MANGALURU',color='blue')
plt.plot(Years,kochirain['POSTMONSOON_RAIN (mm/day)'],label='KOCHIN',color='red')
plt.legend(loc='best',fontsize=9)
plt.show()
